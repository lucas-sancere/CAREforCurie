# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
import importlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import csbdeep


from csbdeep.utils import _raise, Path, axes_check_and_normalize,axes_dict, move_image_axes, move_channel_for_backend, backend_channels_last


from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history
from csbdeep.utils.tf import limit_gpu_memory
import matplotlib.pyplot as plt
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd
from externalmodels.unet import *
from csbdeep.io import load_training_data
from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from csbdeep.utils import axes_dict, plot_some, plot_history
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
(X,Y),(X_val, Y_val), axes = load_training_data('/data/u934/service_imagerie/v_kapoor/StarDistTraining/UnetSegmentation.npz',validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
IMG_HEIGHT = X.shape[1]
IMG_WIDTH = X.shape[2]
IMG_CHANNELS = X.shape[c]
print(IMG_HEIGHT , IMG_WIDTH, IMG_CHANNELS )
print(X_val.shape)
# Out:
# number of training images:	 4023
# number of validation images:	 447
# image size (2D):		 (128, 128)
# axes:				 SYXC
# channels in / out:		 1 / 1
# 128 128 1
# (447, 128, 128, 1)

# %%
plt.figure(figsize=(12,5))
plot_some(X[:5],Y[:5])

plt.suptitle('5 training patches (top row: source, bottom row: target)');

# %%
print(X.shape, Y.shape)
# Out:
# (4023, 128, 128, 1) (4023, 128, 128, 1)

# %%
model = build_model_unet((None,None,1), dropout = 0)
model.summary()
model.compile(optimizer=Adam(lr= 0.002), loss=my_binary_crossentropy_mod(weights=(1.0,10.)))
hist = model.fit(X,Y, epochs=20, batch_size=200, validation_split=0.1)
model.save('models/UNet_model.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 8 80          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 8 32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 8 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 8 584         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 8 32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 8 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 8 584         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 8 32          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 8 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 8 584         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 8 32          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 8 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 8 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 1168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 1 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 1 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 1 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 1 2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 1 64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 1 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 1 0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 3 4640        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 3 128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 3 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 3 9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 3 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 3 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 3 9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 3 128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 3 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 1 4624        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 1 64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 1 0           activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 3 0           up_sampling2d_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 4624        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 1 2320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 1 64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 8 1160        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 8 32          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 8 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 8 0           activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 1 0           up_sampling2d_2[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 8 1160        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 8 32          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 8 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 8 584         activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 8 32          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 8 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 8 584         activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 8 32          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 8 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 8 584         activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 8 32          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 8 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 9           activation_20[0][0]
# ==================================================================================================
# Total params: 52,249
# Trainable params: 51,657
# Non-trainable params: 592
# __________________________________________________________________________________________________
# Train on 3620 samples, validate on 403 samples
# Epoch 1/200
# 3620/3620 [==============================] - 25s 7ms/step - loss: 0.8228 - val_loss: 1.1478
# Epoch 2/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.6421 - val_loss: 0.6152
# Epoch 3/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.5865 - val_loss: 0.5724
# Epoch 4/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.5443 - val_loss: 0.5268
# Epoch 5/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.5121 - val_loss: 0.5176
# Epoch 6/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.4828 - val_loss: 0.5233
# Epoch 7/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.4594 - val_loss: 0.5493
# Epoch 8/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.4400 - val_loss: 0.4976
# Epoch 9/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.4210 - val_loss: 0.5426
# Epoch 10/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.4034 - val_loss: 0.4857
# Epoch 11/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3938 - val_loss: 0.5013
# Epoch 12/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3832 - val_loss: 0.4651
# Epoch 13/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3744 - val_loss: 0.4321
# Epoch 14/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3670 - val_loss: 0.4755
# Epoch 15/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3619 - val_loss: 0.4331
# Epoch 16/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3551 - val_loss: 0.4113
# Epoch 17/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3505 - val_loss: 0.3989
# Epoch 18/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3470 - val_loss: 0.3825
# Epoch 19/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3441 - val_loss: 0.3821
# Epoch 20/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3414 - val_loss: 0.3780
# Epoch 21/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3381 - val_loss: 0.3702
# Epoch 22/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3357 - val_loss: 0.3814
# Epoch 23/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3328 - val_loss: 0.3866
# Epoch 24/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3310 - val_loss: 0.3786
# Epoch 25/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3309 - val_loss: 0.3897
# Epoch 26/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3296 - val_loss: 0.3667
# Epoch 27/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3278 - val_loss: 0.3558
# Epoch 28/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3275 - val_loss: 0.3575
# Epoch 29/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3273 - val_loss: 0.3707
# Epoch 30/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3238 - val_loss: 0.3745
# Epoch 31/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3214 - val_loss: 0.3928
# Epoch 32/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3229 - val_loss: 0.3757
# Epoch 33/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3230 - val_loss: 0.3863
# Epoch 34/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3219 - val_loss: 0.3650
# Epoch 35/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3201 - val_loss: 0.4583
# Epoch 36/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3294 - val_loss: 0.4374
# Epoch 37/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3309 - val_loss: 0.4043
# Epoch 38/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3292 - val_loss: 0.3808
# Epoch 39/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3267 - val_loss: 0.3588
# Epoch 40/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3223 - val_loss: 0.3646
# Epoch 41/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3212 - val_loss: 0.3530
# Epoch 42/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3225 - val_loss: 0.3584
# Epoch 43/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3214 - val_loss: 0.3622
# Epoch 44/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3309 - val_loss: 0.4498
# Epoch 45/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3352 - val_loss: 9.2778
# Epoch 46/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3275 - val_loss: 0.5412
# Epoch 47/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3244 - val_loss: 0.3916
# Epoch 48/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3238 - val_loss: 0.3828
# Epoch 49/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3247 - val_loss: 0.3711
# Epoch 50/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3241 - val_loss: 0.3599
# Epoch 51/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3200 - val_loss: 0.3494
# Epoch 52/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3197 - val_loss: 0.3562
# Epoch 53/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3195 - val_loss: 0.3521
# Epoch 54/200
# 3620/3620 [==============================] - 18s 5ms/step - loss: 0.3176 - val_loss: 0.3529
# Epoch 55/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3171 - val_loss: 0.3761
# Epoch 56/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3166 - val_loss: 0.3463
# Epoch 57/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3144 - val_loss: 0.3459
# Epoch 58/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3149 - val_loss: 0.3460
# Epoch 59/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3171 - val_loss: 0.3576
# Epoch 60/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3131 - val_loss: 0.3509
# Epoch 61/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3134 - val_loss: 0.3620
# Epoch 62/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3133 - val_loss: 0.3448
# Epoch 63/200
# 3620/3620 [==============================] - 19s 5ms/step - loss: 0.3121 - val_loss: 0.3537
# Epoch 64/200
#  600/3620 [===>..........................] - ETA: 14s - loss: 0.3193
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ac6216be7a1c> in <module>()
#       2 model.summary()
#       3 model.compile(optimizer=Adam(lr= 0.002), loss=my_binary_crossentropy(weights=(1.0,10.)))
# ----> 4 hist = model.fit(X,Y, epochs=200, batch_size=200, validation_split=0.1)
#       5 model.save('models/UNet_model.h5')
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
Y_pred = model.predict(X_val)

# %%
plt.figure(figsize=(16,4))
plot_some(X_val[:10],Y_pred[:10])
plt.show()
