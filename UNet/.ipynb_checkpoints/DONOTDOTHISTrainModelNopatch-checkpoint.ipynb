# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from glob import glob
from tqdm import tqdm
from tifffile import imread
from csbdeep.utils import Path, normalize
from externalmodels.unet import *
from stardist import fill_label_holes, random_label_cmap
from stardist import Config, StarDist, StarDistData

np.random.seed(42)
lbl_cmap = random_label_cmap()
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
X = sorted(glob('/data/u934/service_imagerie/v_kapoor/StarDistTraining/train/SmallTrain/images/*.tif'))
Y = sorted(glob('/data/u934/service_imagerie/v_kapoor/StarDistTraining/train/SmallTrain/masks/*.tif'))
assert all(Path(x).name==Path(y).name for x,y in zip(X,Y))

# %%
X = list(map(imread,X))
Y = list(map(imread,Y))

# %%
X = [normalize(x,1,99.8) for x in tqdm(X)]
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 553.52it/s]

# %%
rng = np.random.RandomState(42)
ind = rng.permutation(len(X))
n_val = int(round(0.15 * len(X)))
ind_train, ind_val = ind[:-n_val], ind[-n_val:]
X_val, Y_val = [X[i] for i in ind_val]  , [Y[i] for i in ind_val]
X_trn, Y_trn = [X[i] for i in ind_train], [Y[i] for i in ind_train] 
print('number of images: %3d' % len(X))
print('- training:       %3d' % len(X_trn))
print('- validation:     %3d' % len(X_val))
# Out:
# number of images:  10
# - training:         8
# - validation:       2

# %%
i = 1
img, lbl = X[i], Y[i]
plt.figure(figsize=(16,10))
plt.subplot(121); plt.imshow(img,cmap='gray');   plt.axis('off'); plt.title('Raw image')
plt.subplot(122); plt.imshow(lbl,cmap=lbl_cmap); plt.axis('off'); plt.title('GT labels')
None;

# %%
print(img.shape, lbl.shape)
# Out:
# (256, 256) (256, 256)

# %%
maxshapeX = img.shape[0]
maxshapeY = img.shape[1]
for i in range(len(X)):
     img = X[i]
     if img.shape[0] >= maxshapeX:
            maxshapeX = img.shape[0]
     if img.shape[1] >= maxshapeY:
        maxshapeY = img.shape[1] 

print(maxshapeX, maxshapeY)
# Out:
# 520 696

# %%
Xin = np.zeros((len(X), maxshapeX, maxshapeY ))
Yin = np.zeros((len(Y), maxshapeX, maxshapeY  ))

Xout = np.zeros((len(X), maxshapeX, maxshapeY, 1 ))
Yout = np.zeros((len(Y), maxshapeX, maxshapeY, 1 ))
for i in range(len(X)):   
     img = X[i]
     lbl = Y[i]  
     Xin[i,:img.shape[0],:img.shape[1]] = img[:,:]
     Yin[i,:lbl.shape[0],:lbl.shape[1]] = lbl[:,:]


i = 0
Xout[:,:,:,i] = Xin[:,:,:]
Yout[:,:,:,i] = Yin[:,:,:]
        
print(Xout.shape, Yout.shape)
# Out:
# (10, 520, 696, 1) (10, 520, 696, 1)

# %%
model = build_model_unet((None,None,1), dropout = 0)
model.summary()
model.compile(optimizer=Adam(lr= 0.002), loss=my_binary_crossentropy(weights=(1.0,10.)))
hist = model.fit(Xout,Yout, epochs=200, batch_size=1, validation_split=0.1)
model.save('models/UNet_model.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, None, None, 1 0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 8 80          input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 8 32          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 8 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 8 584         activation_21[0][0]
# ...
