# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
sys.path.append("../HelperFunctions")
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import cv2
from tifffile import imread
from csbdeep.utils import download_and_extract_zip_file, plot_some
from csbdeep.data import RawData, create_patches
from selectrawdata import SelectRawData
# Out:
# Using TensorFlow backend.

# %%
raw_data = SelectRawData.Shuffle_from_folder(
    basepath    = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_CARE_restoration/SpinwideFRAP4_Training_CARE_40x_bin1_3Gfp/',
    source_dirs = ['Low'],
    target_dir  = 'GT',
    axes        = 'ZYX',   
    pattern = '*'
)

# %%
X, Y, XY_axes = create_patches (
    raw_data            = raw_data,
    patch_size          = (16,64,64),   #for bin1 it is 16 64 64 and for bin2 it is  16 32 32
    n_patches_per_image =  64,
    save_file           = '/run/media/sancere/DATA/Lucas_NextonCreated_npz/Training_CARE_restoration_WideNewFiber1_Bin1.npz',
)
# Out:
# ...
#  2619 raw images x    1 transformations   =  2619 images
#  2619 images     x   64 patches per image = 167616 patches in total
# ...
# Input data:
# /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_CARE_restoration/SpinwideFRAP4_Training_CARE_40x_bin1_3Gfp/: target='GT', sources=['Low'], axes='ZYX', pattern='*'
# ...
# Transformations:
# 1 x Identity
# ...
# Patch size:
# 16 x 64 x 64
# ...
# 100%|██████████| 2619/2619 [8:19:30<00:00, 11.44s/it]
# Saving data to /run/media/sancere/DATA/Lucas_NextonCreated_npz/Training_CARE_restoration_WideNewFiber1_Bin1.npz.

# %%
assert X.shape == Y.shape
print("shape of X,Y =", X.shape)
print("axes  of X,Y =", XY_axes)
# Out:
# shape of X,Y = (167616, 1, 16, 64, 64)
# axes  of X,Y = SCZYX

# %%
for i in range(4):
    plt.figure(figsize=(16,4))
    sl = slice(8*i, 8*(i+1)), 0
    plot_some(X[sl],Y[sl],title_list=[np.arange(sl[0].start,sl[0].stop)])
    plt.show()
None;

# %%
raw_data = SelectRawData.Shuffle_from_folder(
    basepath    = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_CARE_restoration/WideNewFiber1_Training_CARE_40x_bin2/',
    source_dirs = ['Low'],
    target_dir  = 'GT',
    axes        = 'ZYX',   
    pattern = '*'
)

# %%
X, Y, XY_axes = create_patches (
    raw_data            = raw_data,
    patch_size          = (16,32,32),   #for bin1 it is 16 64 64 and for bin2 it is  16 32 32
    n_patches_per_image =  64,
    save_file           = '/run/media/sancere/DATA/Lucas_NextonCreated_npz/Training_CARE_restoration_WideNewFiber1_Bin2.npz',
)
# Out:
# ...
#   170 raw images x    1 transformations   =   170 images
#   170 images     x   64 patches per image = 10880 patches in total
# ...
# Input data:
# /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_CARE_restoration/WideNewFiber1_Training_CARE_40x_bin2/: target='GT', sources=['Low'], axes='ZYX', pattern='*'
# ...
# Transformations:
# 1 x Identity
# ...
# Patch size:
# 16 x 32 x 32
# ...
# 100%|██████████| 170/170 [43:18<00:00, 15.28s/it]
# Saving data to /run/media/sancere/DATA/Lucas_NextonCreated_npz/Training_CARE_restoration_WideNewFiber1_Bin2.npz.

# %%
assert X.shape == Y.shape
print("shape of X,Y =", X.shape)
print("axes  of X,Y =", XY_axes)
# Out:
# shape of X,Y = (10880, 1, 16, 32, 32)
# axes  of X,Y = SCZYX

# %%
for i in range(4):
    plt.figure(figsize=(16,4))
    sl = slice(8*i, 8*(i+1)), 0
    plot_some(X[sl],Y[sl],title_list=[np.arange(sl[0].start,sl[0].stop)])
    plt.show()
None;
