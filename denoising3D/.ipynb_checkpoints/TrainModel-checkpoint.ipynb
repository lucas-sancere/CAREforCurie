# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history
from csbdeep.utils.tf import limit_gpu_memory
from csbdeep.io import load_training_data
from csbdeep.models import Config, CARE
# Out:
# Using TensorFlow backend.

# %%
(X,Y), (X_val,Y_val), axes = load_training_data('/data/u934/service_imagerie/v_kapoor/CurieTrainingDatasets/Drosophilla/BorialisSiS2Train.npz', validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 84787
# number of validation images:	 9421
# image size (3D):		 (16, 64, 64)
# axes:				 SZYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %%
config = Config(axes, n_channel_in, n_channel_out, train_steps_per_epoch=100, unet_n_depth=4,train_epochs= 100, train_batch_size = 16)
print(config)
vars(config)
# Out:
# Config(axes='ZYXC', n_channel_in=1, n_channel_out=1, n_dim=3, probabilistic=False, train_batch_size=16, train_checkpoint='weights_best.h5', train_epochs=100, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'patience': 10, 'factor': 0.5}, train_steps_per_epoch=100, train_tensorboard=True, unet_input_shape=(None, None, None, 1), unet_kern_size=3, unet_last_activation='linear', unet_n_depth=4, unet_n_first=32, unet_residual=True)
# {'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'n_dim': 3,
#  'probabilistic': False,
#  'train_batch_size': 16,
#  'train_checkpoint': 'weights_best.h5',
#  'train_epochs': 100,
#  'train_learning_rate': 0.0004,
#  'train_loss': 'mae',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'train_steps_per_epoch': 100,
#  'train_tensorboard': True,
#  'unet_input_shape': (None, None, None, 1),
#  'unet_kern_size': 3,
#  'unet_last_activation': 'linear',
#  'unet_n_depth': 4,
#  'unet_n_first': 32,
#  'unet_residual': True}

# %%
model = CARE(config, 'BorialisS1S2FlorisMidNoiseModel', basedir='/data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels')
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/csbdeep/models/care_standard.py:99: UserWarning: output path for model already exists, files may be overwritten: /data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/DrosophilaLowestNoisemodel
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 527s 5s/step - loss: 0.1308 - mse: 0.0321 - mae: 0.1308 - val_loss: 0.1153 - val_mse: 0.0252 - val_mae: 0.1153
# Epoch 2/100
# 100/100 [==============================] - 526s 5s/step - loss: 0.1099 - mse: 0.0241 - mae: 0.1099 - val_loss: 0.1119 - val_mse: 0.0237 - val_mae: 0.1119
# Epoch 3/100
# 100/100 [==============================] - 529s 5s/step - loss: 0.1073 - mse: 0.0228 - mae: 0.1073 - val_loss: 0.1096 - val_mse: 0.0249 - val_mae: 0.1096
# Epoch 4/100
# 100/100 [==============================] - 526s 5s/step - loss: 0.1084 - mse: 0.0229 - mae: 0.1084 - val_loss: 0.1075 - val_mse: 0.0240 - val_mae: 0.1075
# Epoch 5/100
# 100/100 [==============================] - 527s 5s/step - loss: 0.1065 - mse: 0.0227 - mae: 0.1065 - val_loss: 0.1073 - val_mse: 0.0219 - val_mae: 0.1073
# Epoch 6/100
# 100/100 [==============================] - 524s 5s/step - loss: 0.1043 - mse: 0.0215 - mae: 0.1043 - val_loss: 0.1058 - val_mse: 0.0230 - val_mae: 0.1058
# Epoch 7/100
# 100/100 [==============================] - 525s 5s/step - loss: 0.1035 - mse: 0.0208 - mae: 0.1035 - val_loss: 0.1127 - val_mse: 0.0262 - val_mae: 0.1127
# Epoch 8/100
# 100/100 [==============================] - 525s 5s/step - loss: 0.1033 - mse: 0.0208 - mae: 0.1033 - val_loss: 0.1010 - val_mse: 0.0199 - val_mae: 0.1010
# Epoch 9/100
# 100/100 [==============================] - 524s 5s/step - loss: 0.1020 - mse: 0.0205 - mae: 0.1020 - val_loss: 0.1017 - val_mse: 0.0197 - val_mae: 0.1017
# Epoch 10/100
# 100/100 [==============================] - 524s 5s/step - loss: 0.1015 - mse: 0.0199 - mae: 0.1015 - val_loss: 0.1056 - val_mse: 0.0202 - val_mae: 0.1056
# Epoch 11/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.1000 - mse: 0.0195 - mae: 0.1000 - val_loss: 0.1023 - val_mse: 0.0214 - val_mae: 0.1023
# Epoch 12/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.1036 - mse: 0.0206 - mae: 0.1036 - val_loss: 0.1010 - val_mse: 0.0206 - val_mae: 0.1010
# Epoch 13/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.1010 - mse: 0.0204 - mae: 0.1010 - val_loss: 0.1029 - val_mse: 0.0215 - val_mae: 0.1029
# Epoch 14/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0975 - mse: 0.0188 - mae: 0.0975 - val_loss: 0.1003 - val_mse: 0.0195 - val_mae: 0.1003
# Epoch 15/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.0993 - mse: 0.0193 - mae: 0.0993 - val_loss: 0.1027 - val_mse: 0.0194 - val_mae: 0.1027
# Epoch 16/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.1009 - mse: 0.0201 - mae: 0.1009 - val_loss: 0.0999 - val_mse: 0.0205 - val_mae: 0.0999
# Epoch 17/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.1001 - mse: 0.0199 - mae: 0.1001 - val_loss: 0.1017 - val_mse: 0.0214 - val_mae: 0.1017
# Epoch 18/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.1024 - mse: 0.0206 - mae: 0.1024 - val_loss: 0.1001 - val_mse: 0.0200 - val_mae: 0.1001
# Epoch 19/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.1014 - mse: 0.0209 - mae: 0.1014 - val_loss: 0.0994 - val_mse: 0.0195 - val_mae: 0.0994
# Epoch 20/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.0973 - mse: 0.0186 - mae: 0.0973 - val_loss: 0.0999 - val_mse: 0.0190 - val_mae: 0.0999
# Epoch 21/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.0994 - mse: 0.0193 - mae: 0.0994 - val_loss: 0.0988 - val_mse: 0.0201 - val_mae: 0.0988
# Epoch 22/100
# 100/100 [==============================] - 592s 6s/step - loss: 0.0977 - mse: 0.0188 - mae: 0.0977 - val_loss: 0.0993 - val_mse: 0.0193 - val_mae: 0.0993
# Epoch 23/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0977 - mse: 0.0191 - mae: 0.0977 - val_loss: 0.0991 - val_mse: 0.0201 - val_mae: 0.0991
# Epoch 24/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.1001 - mse: 0.0197 - mae: 0.1001 - val_loss: 0.0992 - val_mse: 0.0196 - val_mae: 0.0992
# Epoch 25/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.0995 - mse: 0.0195 - mae: 0.0995 - val_loss: 0.0989 - val_mse: 0.0192 - val_mae: 0.0989
# Epoch 26/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0977 - mse: 0.0187 - mae: 0.0977 - val_loss: 0.0981 - val_mse: 0.0197 - val_mae: 0.0981
# Epoch 27/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.0988 - mse: 0.0194 - mae: 0.0988 - val_loss: 0.1008 - val_mse: 0.0189 - val_mae: 0.1008
# Epoch 28/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0963 - mse: 0.0184 - mae: 0.0963 - val_loss: 0.0977 - val_mse: 0.0190 - val_mae: 0.0977
# Epoch 29/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0962 - mse: 0.0181 - mae: 0.0962 - val_loss: 0.0980 - val_mse: 0.0197 - val_mae: 0.0980
# Epoch 30/100
# 100/100 [==============================] - 523s 5s/step - loss: 0.1000 - mse: 0.0200 - mae: 0.1000 - val_loss: 0.0980 - val_mse: 0.0191 - val_mae: 0.0980
# Epoch 31/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.1000 - mse: 0.0198 - mae: 0.1000 - val_loss: 0.0997 - val_mse: 0.0199 - val_mae: 0.0997
# Epoch 32/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.
100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0951 - mse: 0.0181 - mae: 0.0951 - val_loss: 0.0958 - val_mse: 0.0182 - val_mae: 0.0958
# Epoch 81/100
# 100/100 [==============================] - 522s 5s/step - loss: 0.0976 - mse: 0.0194 - mae: 0.0976 - val_loss: 0.0936 - val_mse: 0.0175 - val_mae: 0.0936
# Epoch 82/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0924 - mse: 0.0170 - mae: 0.0924 - val_loss: 0.0935 - val_mse: 0.0180 - val_mae: 0.0935
# Epoch 83/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0948 - mse: 0.0181 - mae: 0.0948 - val_loss: 0.0932 - val_mse: 0.0174 - val_mae: 0.0932
# Epoch 84/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0908 - mse: 0.0165 - mae: 0.0908 - val_loss: 0.0932 - val_mse: 0.0169 - val_mae: 0.0932
# Epoch 85/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0943 - mse: 0.0178 - mae: 0.0943 - val_loss: 0.0951 - val_mse: 0.0173 - val_mae: 0.0951
# Epoch 86/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0943 - mse: 0.0183 - mae: 0.0943 - val_loss: 0.0907 - val_mse: 0.0170 - val_mae: 0.0907
# Epoch 87/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0903 - mse: 0.0164 - mae: 0.0903 - val_loss: 0.0934 - val_mse: 0.0178 - val_mae: 0.0934
# Epoch 88/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0926 - mse: 0.0171 - mae: 0.0926 - val_loss: 0.0950 - val_mse: 0.0191 - val_mae: 0.0950
# Epoch 89/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0914 - mse: 0.0170 - mae: 0.0914 - val_loss: 0.0912 - val_mse: 0.0160 - val_mae: 0.0912
# Epoch 90/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0900 - mse: 0.0163 - mae: 0.0900 - val_loss: 0.0906 - val_mse: 0.0169 - val_mae: 0.0906
# Epoch 91/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0920 - mse: 0.0174 - mae: 0.0920 - val_loss: 0.0915 - val_mse: 0.0176 - val_mae: 0.0915
# Epoch 92/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0899 - mse: 0.0159 - mae: 0.0899 - val_loss: 0.0894 - val_mse: 0.0158 - val_mae: 0.0894
# Epoch 93/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0905 - mse: 0.0163 - mae: 0.0905 - val_loss: 0.0900 - val_mse: 0.0167 - val_mae: 0.0900
# Epoch 94/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0904 - mse: 0.0164 - mae: 0.0904 - val_loss: 0.0909 - val_mse: 0.0158 - val_mae: 0.0909
# Epoch 95/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0886 - mse: 0.0153 - mae: 0.0886 - val_loss: 0.0894 - val_mse: 0.0161 - val_mae: 0.0894
# Epoch 96/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0914 - mse: 0.0166 - mae: 0.0914 - val_loss: 0.0886 - val_mse: 0.0157 - val_mae: 0.0886
# Epoch 97/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0893 - mse: 0.0161 - mae: 0.0893 - val_loss: 0.0893 - val_mse: 0.0164 - val_mae: 0.0893
# Epoch 98/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0888 - mse: 0.0158 - mae: 0.0888 - val_loss: 0.0901 - val_mse: 0.0157 - val_mae: 0.0901
# Epoch 99/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0908 - mse: 0.0166 - mae: 0.0908 - val_loss: 0.0891 - val_mse: 0.0165 - val_mae: 0.0891
# Epoch 100/100
# 100/100 [==============================] - 521s 5s/step - loss: 0.0885 - mse: 0.0157 - mae: 0.0885 - val_loss: 0.0897 - val_mse: 0.0157 - val_mae: 0.0897

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);
# Out:
# ['loss', 'lr', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %%
model.export_TF()
# Out:
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmpaiguyviv/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/DrosophilaLowestNoisemodel/TF_SavedModel.zip
