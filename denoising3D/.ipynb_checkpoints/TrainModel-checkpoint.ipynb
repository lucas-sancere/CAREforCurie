# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history
from csbdeep.utils.tf import limit_gpu_memory
from csbdeep.io import load_training_data
from csbdeep.models import Config, CARE
# Out:
# Using TensorFlow backend.

# %%
(X,Y), (X_val,Y_val), axes = load_training_data('/data/u934/service_imagerie/v_kapoor/CurieTrainingDatasets/Drosophilla/BorialisSiS2Train.npz', validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 137779
# number of validation images:	 15309
# image size (3D):		 (16, 64, 64)
# axes:				 SZYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %%
config = Config(axes, n_channel_in, n_channel_out, train_steps_per_epoch=100, unet_n_depth=4,train_epochs= 100, train_batch_size = 16)
print(config)
vars(config)
# Out:
# Config(axes='ZYXC', n_channel_in=1, n_channel_out=1, n_dim=3, probabilistic=False, train_batch_size=16, train_checkpoint='weights_best.h5', train_epochs=100, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'factor': 0.5, 'patience': 10}, train_steps_per_epoch=100, train_tensorboard=True, unet_input_shape=(None, None, None, 1), unet_kern_size=3, unet_last_activation='linear', unet_n_depth=4, unet_n_first=32, unet_residual=True)
# {'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'n_dim': 3,
#  'probabilistic': False,
#  'train_batch_size': 16,
#  'train_checkpoint': 'weights_best.h5',
#  'train_epochs': 100,
#  'train_learning_rate': 0.0004,
#  'train_loss': 'mae',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'train_steps_per_epoch': 100,
#  'train_tensorboard': True,
#  'unet_input_shape': (None, None, None, 1),
#  'unet_kern_size': 3,
#  'unet_last_activation': 'linear',
#  'unet_n_depth': 4,
#  'unet_n_first': 32,
#  'unet_residual': True}

# %%
model = CARE(config, 'BorialisS1S2FlorisMidNoiseModel', basedir='/data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels')

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 750s 7s/step - loss: 0.0854 - mse: 0.0131 - mae: 0.0854 - val_loss: 0.0749 - val_mse: 0.0096 - val_mae: 0.0749
# Epoch 2/100
# 100/100 [==============================] - 743s 7s/step - loss: 0.0727 - mse: 0.0092 - mae: 0.0727 - val_loss: 0.0716 - val_mse: 0.0089 - val_mae: 0.0716
# Epoch 3/100
# 100/100 [==============================] - 743s 7s/step - loss: 0.0710 - mse: 0.0087 - mae: 0.0710 - val_loss: 0.0704 - val_mse: 0.0085 - val_mae: 0.0704
# Epoch 4/100
# 100/100 [==============================] - 743s 7s/step - loss: 0.0702 - mse: 0.0085 - mae: 0.0702 - val_loss: 0.0700 - val_mse: 0.0084 - val_mae: 0.0700
# Epoch 5/100
# 100/100 [==============================] - 743s 7s/step - loss: 0.0706 - mse: 0.0086 - mae: 0.0706 - val_loss: 0.0695 - val_mse: 0.0083 - val_mae: 0.0695
# Epoch 6/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0701 - mse: 0.0085 - mae: 0.0701 - val_loss: 0.0693 - val_mse: 0.0083 - val_mae: 0.0693
# Epoch 7/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0704 - mse: 0.0086 - mae: 0.0704 - val_loss: 0.0692 - val_mse: 0.0083 - val_mae: 0.0692
# Epoch 8/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0694 - mse: 0.0083 - mae: 0.0694 - val_loss: 0.0692 - val_mse: 0.0083 - val_mae: 0.0692
# Epoch 9/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0693 - mse: 0.0083 - mae: 0.0693 - val_loss: 0.0691 - val_mse: 0.0083 - val_mae: 0.0691
# Epoch 10/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0692 - mse: 0.0083 - mae: 0.0692 - val_loss: 0.0691 - val_mse: 0.0082 - val_mae: 0.0691
# Epoch 11/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0696 - mse: 0.0084 - mae: 0.0696 - val_loss: 0.0696 - val_mse: 0.0085 - val_mae: 0.0696
# Epoch 12/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0695 - mse: 0.0083 - mae: 0.0695 - val_loss: 0.0691 - val_mse: 0.0082 - val_mae: 0.0691
# Epoch 13/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0692 - mse: 0.0083 - mae: 0.0692 - val_loss: 0.0693 - val_mse: 0.0082 - val_mae: 0.0693
# Epoch 14/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0693 - mse: 0.0083 - mae: 0.0693 - val_loss: 0.0690 - val_mse: 0.0082 - val_mae: 0.0690
# Epoch 15/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0695 - mse: 0.0084 - mae: 0.0695 - val_loss: 0.0694 - val_mse: 0.0084 - val_mae: 0.0694
# Epoch 16/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0690 - val_mse: 0.0083 - val_mae: 0.0690
# Epoch 17/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0693 - mse: 0.0083 - mae: 0.0693 - val_loss: 0.0691 - val_mse: 0.0082 - val_mae: 0.0691
# Epoch 18/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0697 - mse: 0.0084 - mae: 0.0697 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 19/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0697 - mse: 0.0084 - mae: 0.0697 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 20/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0695 - mse: 0.0084 - mae: 0.0695 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 21/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0689 - mse: 0.0082 - mae: 0.0689 - val_loss: 0.0693 - val_mse: 0.0084 - val_mae: 0.0693
# Epoch 22/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 23/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0686 - mse: 0.0081 - mae: 0.0686 - val_loss: 0.0689 - val_mse: 0.0082 - val_mae: 0.0689
# Epoch 24/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0689 - mse: 0.0082 - mae: 0.0689 - val_loss: 0.0687 - val_mse: 0.0081 - val_mae: 0.0687
# Epoch 25/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0694 - mse: 0.0083 - mae: 0.0694 - val_loss: 0.0690 - val_mse: 0.0082 - val_mae: 0.0690
# Epoch 26/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0691 - mse: 0.0083 - mae: 0.0691 - val_loss: 0.0687 - val_mse: 0.0082 - val_mae: 0.0687
# Epoch 27/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0687 - val_mse: 0.0081 - val_mae: 0.0687
# Epoch 28/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0687 - mse: 0.0082 - mae: 0.0687 - val_loss: 0.0689 - val_mse: 0.0083 - val_mae: 0.0689
# Epoch 29/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0689 - mse: 0.0082 - mae: 0.0689 - val_loss: 0.0689 - val_mse: 0.0083 - val_mae: 0.0689
# Epoch 30/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0695 - mse: 0.0084 - mae: 0.0695 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 31/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0694 - mse: 0.0084 - mae: 0.0694 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 32/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0684 - mse: 0.0081 - mae: 0.0684 - val_loss: 0.0687 - val_mse: 0.0081 - val_mae: 0.0687
# Epoch 33/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0692 - mse: 0.0083 - mae: 0.0692 - val_loss: 0.0686 - val_mse: 0.0081 - val_mae: 0.0686
# Epoch 34/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0687 - mse: 0.0082 - mae: 0.0687 - val_loss: 0.0691 - val_mse: 0.0082 - val_mae: 0.0691
# Epoch 35/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0687 - val_mse: 0.0082 - val_mae: 0.0687
# Epoch 36/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0694 - mse: 0.0083 - mae: 0.0694 - val_loss: 0.0687 - val_mse: 0.0082 - val_mae: 0.0687
# Epoch 37/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0688 - val_mse: 0.0081 - val_mae: 0.0688
# Epoch 38/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0694 - mse: 0.0083 - mae: 0.0694 - val_loss: 0.0694 - val_mse: 0.0082 - val_mae: 0.0694
# Epoch 39/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0686 - val_mse: 0.0082 - val_mae: 0.0686
# Epoch 40/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0689 - val_mse: 0.0083 - val_mae: 0.0689
# Epoch 41/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0686 - mse: 0.0081 - mae: 0.0686 - val_loss: 0.0687 - val_mse: 0.0082 - val_mae: 0.0687
# Epoch 42/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0681 - mse: 0.0080 - mae: 0.0681 - val_loss: 0.0685 - val_mse: 0.0081 - val_mae: 0.0685
# Epoch 43/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0686 - mse: 0.0082 - mae: 0.0686 - val_loss: 0.0688 - val_mse: 0.0083 - val_mae: 0.0688
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 44/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0687 - mse: 0.0082 - mae: 0.0687 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 45/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 46/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0684 - mse: 0.0081 - mae: 0.0684 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 47/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 48/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0681 - mse: 0.0080 - mae: 0.0681 - val_loss: 0.0686 - val_mse: 0.0081 - val_mae: 0.0686
# Epoch 49/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 50/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0690 - mse: 0.0083 - mae: 0.0690 - val_loss: 0.0688 - val_mse: 0.0082 - val_mae: 0.0688
# Epoch 51/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0687 - mse: 0.0083 - mae: 0.0687 - val_loss: 0.0685 - val_mse: 0.0081 - val_mae: 0.0685
# Epoch 52/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0695 - mse: 0.0084 - mae: 0.0695 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 53/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0679 - mse: 0.0080 - mae: 0.0679 - val_loss: 0.0687 - val_mse: 0.0082 - val_mae: 0.0687
# Epoch 54/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0681 - mse: 0.0080 - mae: 0.0681 - val_loss: 0.0685 - val_mse: 0.0081 - val_mae: 0.0685
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 55/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 56/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0682 - mse: 0.0080 - mae: 0.0682 - val_loss: 0.0686 - val_mse: 0.0081 - val_mae: 0.0686
# Epoch 57/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0682 - mse: 0.0081 - mae: 0.0682 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 58/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0685 - mse: 0.0081 - mae: 0.0685 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 59/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 60/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0685 - mse: 0.0081 - mae: 0.0685 - val_loss: 0.0684 - val_mse: 0.0081 - val_mae: 0.0684
# Epoch 61/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0687 - mse: 0.0082 - mae: 0.0687 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 62/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 63/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0681 - mse: 0.0081 - mae: 0.0681 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 64/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0679 - mse: 0.0080 - mae: 0.0679 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 65/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 66/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0681 - mse: 0.0080 - mae: 0.0681 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 67/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 68/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0685 - mse: 0.0081 - mae: 0.0685 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 69/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 70/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 71/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0679 - mse: 0.0080 - mae: 0.0679 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 72/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0678 - mse: 0.0080 - mae: 0.0678 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 73/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0676 - mse: 0.0079 - mae: 0.0676 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 74/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 75/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 76/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0683 - val_mse: 0.0081 - val_mae: 0.0683
# Epoch 77/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0688 - mse: 0.0082 - mae: 0.0688 - val_loss: 0.0686 - val_mse: 0.0082 - val_mae: 0.0686
# Epoch 78/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0684 - mse: 0.0081 - mae: 0.0684 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 79/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0686 - mse: 0.0081 - mae: 0.0686 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 80/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0685 - mse: 0.0081 - mae: 0.0685 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 81/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0686 - mse: 0.0082 - mae: 0.0686 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 82/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 83/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0679 - mse: 0.0080 - mae: 0.0679 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 84/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0684 - mse: 0.0081 - mae: 0.0684 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 85/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0685 - mse: 0.0081 - mae: 0.0685 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 86/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 87/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0684 - mse: 0.0081 - mae: 0.0684 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
# Epoch 88/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0681 - mse: 0.0080 - mae: 0.0681 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 89/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0677 - mse: 0.0080 - mae: 0.0677 - val_loss: 0.0681 - val_mse: 0.0081 - val_mae: 0.0681
# Epoch 90/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0675 - mse: 0.0079 - mae: 0.0675 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 91/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0679 - mse: 0.0080 - mae: 0.0679 - val_loss: 0.0682 - val_mse: 0.0081 - val_mae: 0.0682
# Epoch 92/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0682 - mse: 0.0081 - mae: 0.0682 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682
# Epoch 93/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0680 - mse: 0.0081 - mae: 0.0680 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 94/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
# Epoch 95/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0686 - mse: 0.0082 - mae: 0.0686 - val_loss: 0.0681 - val_mse: 0.0081 - val_mae: 0.0681
# Epoch 96/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
# Epoch 97/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0679 - mse: 0.0080 - mae: 0.0679 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
# Epoch 98/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0676 - mse: 0.0079 - mae: 0.0676 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
# Epoch 99/100
# 100/100 [==============================] - 741s 7s/step - loss: 0.0680 - mse: 0.0080 - mae: 0.0680 - val_loss: 0.0681 - val_mse: 0.0080 - val_mae: 0.0681
# Epoch 100/100
# 100/100 [==============================] - 742s 7s/step - loss: 0.0683 - mse: 0.0081 - mae: 0.0683 - val_loss: 0.0682 - val_mse: 0.0080 - val_mae: 0.0682

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);
# Out:
# ['loss', 'lr', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %%
model.export_TF()
# Out:
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmp5qtmoun5/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/BorialisS1S2FlorisMidNoiseModel/TF_SavedModel.zip
