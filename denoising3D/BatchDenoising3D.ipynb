# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import glob

from tifffile import imread
from csbdeep.utils import Path, download_and_extract_zip_file, plot_some
from csbdeep.io import save_tiff_imagej_compatible
from csbdeep.models import CARE
# Out:
# Using TensorFlow backend.

# %%
basedirLow = '/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/'
basedirResults = '/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/'
ModelName = 'DenoisingS1S2_model'
BaseDir = 'models'

# %%
Raw_path = os.path.join(basedirLow, '*TIF')
Rawfiles = []
Names = []
filesRaw = glob.glob(Raw_path)
for fname in filesRaw:
        x = imread(fname)
        Names.append(fname)
        
        Rawfiles.append(x)
Rawfiles.sort
Names.sort
axes = 'ZYX'
print('total number of images to be restored = ', len(Rawfiles))
print('image size =', x.shape)
print('image axes =', axes)
#plot first three file data
count = min(3, len(Rawfiles))

for i in range(0, count):
    plt.figure(figsize = (16,10))
    plot_some(np.stack([Rawfiles[i]]), title_list= [[ 'Input images (maximum projection)' ]])
# Out:
# total number of images to be restored =  120
# image size = (26, 2048, 2048)
# image axes = ZYX

# %%
model = CARE(config = None, name = ModelName, basedir = BaseDir)
# Out:
# Loading network weights from 'weights_best.h5'.

# %%
# %%time
Restoredfiles = []
for x in Rawfiles:
    restored = model.predict(x, axes)
    Restoredfiles.append(restored)
# Out:
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# Out of memory, retrying with n_tiles = 4
# Out of memory, retrying with n_tiles = 8
# Out of memory, retrying with n_tiles = 16
# Out of memory, retrying with n_tiles = 32
# Out of memory, retrying with n_tiles = 64
# Out of memory, retrying with n_tiles = 128
# Out of memory, retrying with n_tiles = 256
# Out of memory, retrying with n_tiles = 512
# CPU times: user 20h 52min 53s, sys: 10h 43min 54s, total: 1d 7h 36min 47s
# Wall time: 1d 6h 54min 49s

# %%
Path(basedirResults).mkdir(exist_ok = True)
for i in range(0, len(Names)):
   print('Saving file' +  basedirResults + '%s_' + os.path.basename(Names[i]))
   save_tiff_imagej_compatible((basedirResults + '%s_' + os.path.basename(Names[i])) % model.name, Restoredfiles[i], axes)
# Out:
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t25.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t4.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t22.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t8.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t3.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t12.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t6.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t1.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t15.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t20.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t19.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t30.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t27.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t17.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t29.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t10.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t28.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t3.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t16.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t11.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t4.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t21.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t26.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t18.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t13.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t9.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t14.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t24.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t23.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t7.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t11.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t16.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t28.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t18.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t26.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t21.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t14.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t13.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t7.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t23.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t2.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t9.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t24.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t5.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t22.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t6.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t25.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t1.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t15.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t12.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t8.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t30.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t27.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t19.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t20.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t10.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t5.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t29.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t2.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t17.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t26.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t2.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t18.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t21.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t5.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t11.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t28.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t16.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t8.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t23.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t24.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t1.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t14.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t13.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t6.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t15.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t12.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t22.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t25.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t4.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t10.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t29.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t8.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t17.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t3.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t27.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t19.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t6.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t30.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t20.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t1.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t12.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t7.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t15.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t25.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t9.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t22.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t29.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t17.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t10.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t20.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t4.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t27.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s2_t3.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s1_t19.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t30.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t21.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t26.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t7.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t18.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t28.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t16.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t2.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t9.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t5.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t11.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t24.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s4_t23.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t13.TIF
# Saving file/data/u934/service_imagerie/v_kapoor/CAREPairData/part1/results/%s_40x_bin1_05_5min_1_w2CSU-488_s3_t14.TIF

# %%
#Plot some restored files
for  i  in  range(0,  count):
      plt.figure(figsize=(16,10))
      plot_some(np.stack([Restoredfiles[i]]),
          title_list=[['CARE (maximum projection)']], 
          pmin=2,pmax=99.8);
      print('Filename = ', Names[i])
# Out:
# Filename =  /data/u934/service_imagerie/v_kapoor/CAREPairData/part1/40x_bin1_05_5min_1_w2CSU-488_s3_t25.TIF
# Filename =  /data/u934/service_imagerie/v_kapoor/CAREPairData/part1/40x_bin1_05_5min_1_w2CSU-488_s3_t4.TIF
# Filename =  /data/u934/service_imagerie/v_kapoor/CAREPairData/part1/40x_bin1_05_5min_1_w2CSU-488_s3_t22.TIF
