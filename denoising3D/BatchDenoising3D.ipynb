# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import glob
from csbdeep.utils.tf import limit_gpu_memory

from tifffile import imread
from csbdeep.utils import Path, download_and_extract_zip_file, plot_some
from csbdeep.io import save_tiff_imagej_compatible
from csbdeep.models import CARE
# Out:
# Using TensorFlow backend.

# %%
basedirLow = '/data/u934/service_imagerie/v_kapoor/Fl4-2-Var/wt_ECadGFPki-hetero_24pre29_bin140x_mov6/'
basedirResults3D = '/data/u934/service_imagerie/v_kapoor/Fl4-2-Var/wt_ECadGFPki-hetero_24pre29_bin140x_mov6/3DResults/'
basedirResults2D = '/data/u934/service_imagerie/v_kapoor/Fl4-2-Var/wt_ECadGFPki-hetero_24pre29_bin140x_mov6/MaxProjectionResults/'

ModelName = 'BorialisS1S2FlorisMidNoiseModel'
BaseDir = '/data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/'
Path(basedirResults3D).mkdir(exist_ok = True)
Path(basedirResults2D).mkdir(exist_ok = True)

# %%
model = CARE(config = None, name = ModelName, basedir = BaseDir)
# Out:
# Loading network weights from 'weights_best.h5'.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# ResourceExhaustedError: OOM when allocating tensor with shape[3,3,3,512,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: up_level_3_no_0/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=9667068, _device="/job:localhost/replica:0/task:0/device:GPU:0"](middle_2/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-3-a888ab54321e> in <module>()
# ----> 1 model = CARE(config = None, name = ModelName, basedir = BaseDir)
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py in __init__(self, config, name, basedir)
#      89         self.keras_model = self._build()
#      90         if config is None:
# ---> 91             self._find_and_load_weights()
#      92
#      93
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py in wrapper(*args, **kwargs)
#     116                     warn is False or warnings.warn("Suppressing call of '%s' (due to basedir=None)." % f.__name__)
#     117                 else:
# --> 118                     return f(*args, **kwargs)
#     119             return wrapper
#     120         return _suppress_without_basedir
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py in _find_and_load_weights(self, prefer)
#     156         weights_chosen = weights_preferred[0] if len(weights_preferred)>0 else weights_files[0]
#     157         print("Loading network weights from '%s'." % weights_chosen.name)
# --> 158         self.load_weights(weights_chosen.name)
#     159
#     160
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py in wrapper(*args, **kwargs)
#     116                     warn is False or warnings.warn("Suppressing call of '%s' (due to basedir=None)." % f.__name__)
#     117                 else:
# --> 118                     return f(*args, **kwargs)
#     119             return wrapper
#     120         return _suppress_without_basedir
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py in load_weights(self, name)
#     181             Name of HDF5 weight file (as saved during or after training).
#     182         """
# --> 183         self.keras_model.load_weights(str(self.logdir/name))
#     184
#     185
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1159             else:
#    1160                 saving.load_weights_from_hdf5_group(
# -> 1161                     f, self.layers, reshape=reshape)
#    1162
#    1163     def _updated_config(self):
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/engine/saving.py in load_weights_from_hdf5_group(f, layers, reshape)
#     926                              ' elements.')
#     927         weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 928     K.batch_set_value(weight_value_tuples)
#     929
#     930
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2438             assign_ops.append(assign_op)
#    2439             feed_dict[assign_placeholder] = value
# -> 2440         get_session().run(assign_ops, feed_dict=feed_dict)
#    2441
#    2442
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     202                     v._keras_initialized = True
#     203                 if uninitialized_vars:
# --> 204                     session.run(tf.variables_initializer(uninitialized_vars))
#     205     # hack for list_devices() function.
#     206     # list_devices() function is not available under tensorflow r1.3.
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1372         except KeyError:
#    1373           pass
# -> 1374       raise type(e)(node_def, op, message)
#    1375
#    1376   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[3,3,3,512,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: up_level_3_no_0/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=9667068, _device="/job:localhost/replica:0/task:0/device:GPU:0"](middle_2/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'up_level_3_no_0/random_uniform/RandomUniform', defined at:
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-a888ab54321e>", line 1, in <module>
#     model = CARE(config = None, name = ModelName, basedir = BaseDir)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py", line 89, in __init__
#     self.keras_model = self._build()
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/models/care_standard.py", line 171, in _build
#     )(self.config.unet_input_shape)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/internals/nets.py", line 100, in _build_this
#     return custom_unet(input_shape, last_activation, n_depth, n_first, (kern_size,)*n_dim, pool_size=(2,)*n_dim, n_channel_out=n_channel_out, residual=residual, prob_out=prob_out)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/internals/nets.py", line 43, in custom_unet
#     n_conv_per_depth=n_conv_per_depth, pool=pool_size)(input)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/internals/blocks.py", line 117, in _func
#     batch_norm=batch_norm, name=_name("up_level_%s_no_%s" % (n, i)))(layer)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/csbdeep/internals/blocks.py", line 49, in _func
#     s = Conv3D(n_filter, (n1, n2, n3), padding=border_mode, kernel_initializer=init, activation=activation, **kwargs)(lay)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/engine/base_layer.py", line 431, in __call__
#     self.build(unpack_singleton(input_shapes))
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/layers/convolutional.py", line 138, in build
#     constraint=self.kernel_constraint)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/engine/base_layer.py", line 249, in add_weight
#     weight = K.variable(initializer(shape),
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/initializers.py", line 218, in __call__
#     dtype=dtype, seed=self.seed)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py", line 4049, in random_uniform
#     dtype=dtype, seed=seed)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/ops/random_ops.py", line 244, in random_uniform
#     shape, dtype, seed=seed1, seed2=seed2)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/ops/gen_random_ops.py", line 435, in _random_uniform
#     name=name)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3271, in create_op
#     op_def=op_def)
#   File "/data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowLOW/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1650, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[3,3,3,512,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: up_level_3_no_0/random_uniform/RandomUniform = RandomUniform[T=DT_INT32, dtype=DT_FLOAT, seed=87654321, seed2=9667068, _device="/job:localhost/replica:0/task:0/device:GPU:0"](middle_2/random_uniform/shape)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
# %%time

Raw_path = os.path.join(basedirLow, '*tif')


axes = 'ZYX'
smallaxes = 'YX'
filesRaw = glob.glob(Raw_path)

filesRaw.sort
print(len(filesRaw))
for fname in filesRaw:
 
        x = imread(fname)
      
        print('Saving file' +  basedirResults3D + '%s_' + os.path.basename(fname))
        restored = model.predict(x, axes, n_tiles = (1, 8, 16)) 
        projected = np.max(restored, axis = 0)
        save_tiff_imagej_compatible((basedirResults2D + '%s_' + 'MAXProjected' +  os.path.basename(fname)) %  model.name , projected, smallaxes)

        save_tiff_imagej_compatible((basedirResults3D + '%s_' + os.path.basename(fname)) % model.name, restored, axes)
