# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
sys.path.append("../HelperFunctions")
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#import cv2
from tifffile import imread
from csbdeep.utils import download_and_extract_zip_file, plot_some
from csbdeep.data import RawData, create_patches_reduced_target
from selectrawdata import SelectRawData
# Out:
# Using TensorFlow backend.

# %%
raw_data = SelectRawData.Shuffle_from_folder(
    basepath    = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_CARE_projection/WideNewFiber1_Training_CARE_40x_bin1/',
    source_dirs = ['Low','Restored'],
    target_dir  = 'GT',
    axes        = 'ZYX',
    pattern = '*'
    
)

# %%
patch_size = (None,128,128)
n_patches_per_image = 12

X, Y, XY_axes = create_patches_reduced_target (
    raw_data            = raw_data,
    patch_size          = patch_size, #for bin1 it is None 128 128 and for bin2 it is None 64 64
    n_patches_per_image = n_patches_per_image, #32 if patch size = (None, 64, 64)  
    target_axes         = 'YX',
    reduction_axes      = 'Z',
    save_file           = '/run/media/sancere/DATA1/Lucas_NextonCreated_npz/WideNewFiber1_Training_CARE_40x_bin1.npz',
)
# Out:
# Warning: will use at least 95040 MB (79.1%) of available memory.
# ==================================================================
#  2112 raw images x    1 transformations   =  2112 images
#  2112 images     x   12 patches per image = 25344 patches in total
# ==================================================================
# Input data:
# /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_CARE_projection/WideNewFiber1_Training_CARE_40x_bin1/: target='GT', sources=['Low', 'Restored'], axes='ZYX', pattern='*'
# ==================================================================
# Transformations:
# 1 x Broadcast target image to the shape of source
# ==================================================================
# Patch size:
# 30 x 128 x 128
# ==================================================================
# 100%|██████████| 2112/2112 [14:10:35<00:00, 24.16s/it]
# Saving data to /run/media/sancere/DATA1/Lucas_NextonCreated_npz/WideNewFiber1_Training_CARE_40x_bin1.npz.

# %%
ConfigNPZ = open("/run/media/sancere/DATA1/Lucas_NextonCreated_npz/Parameters_Npz/ConfigNPZ_WideNewFiber1_Training_CARE_40x_bin1.txt", "w+") 
ConfigNPZ.write("patch_size = {} \n n_patches_per_image = {}".format(patch_size,n_patches_per_image))
ConfigNPZ.close()

# %%
for i in range(2):
    plt.figure(figsize=(16,4))
    sl = slice(18*i, 18*(i+1)), 0
    plot_some(X[sl],Y[sl],title_list=[np.arange(sl[0].start,sl[0].stop)])
    plt.show()
None;

# %%
from csbdeep.utils import Path

TriggerName = '/home/sancere/NextonDisk_1/TimeTrigger/TTGenData'
Path(TriggerName).mkdir(exist_ok = True)
