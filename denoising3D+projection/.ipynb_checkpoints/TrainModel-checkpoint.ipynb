# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history
from csbdeep.utils.tf import limit_gpu_memory
from csbdeep.io import load_training_data
from csbdeep.models import Config, ProjectionCARE
# Out:
# Using TensorFlow backend.

# %%
(X,Y), (X_val,Y_val), axes = load_training_data('/data/u934/service_imagerie/v_kapoor/CurieTrainingDatasets/Drosophilla/DenoisingProjection.npz', validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 23270
# number of validation images:	 2586
# image size (3D):		 (26, 128, 128)
# axes:				 SZYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %%
config = Config(axes, n_channel_in, n_channel_out, unet_n_depth=4,train_epochs= 50,train_steps_per_epoch = 400, train_batch_size = 16, train_reduce_lr={'patience': 5, 'factor': 0.5})
print(config)
vars(config)
# Out:
# Config(axes='ZYXC', n_channel_in=1, n_channel_out=1, n_dim=3, probabilistic=False, train_batch_size=16, train_checkpoint='weights_best.h5', train_epochs=100, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'patience': 5, 'factor': 0.5}, train_steps_per_epoch=400, train_tensorboard=True, unet_input_shape=(None, None, None, 1), unet_kern_size=3, unet_last_activation='linear', unet_n_depth=4, unet_n_first=32, unet_residual=True)
# {'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'n_dim': 3,
#  'probabilistic': False,
#  'train_batch_size': 16,
#  'train_checkpoint': 'weights_best.h5',
#  'train_epochs': 100,
#  'train_learning_rate': 0.0004,
#  'train_loss': 'mae',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 5},
#  'train_steps_per_epoch': 400,
#  'train_tensorboard': True,
#  'unet_input_shape': (None, None, None, 1),
#  'unet_kern_size': 3,
#  'unet_last_activation': 'linear',
#  'unet_n_depth': 4,
#  'unet_n_first': 32,
#  'unet_residual': True}

# %%
model = ProjectionCARE(config, 'DrosophilaDenoisingProjection', basedir='/data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels')
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowpy3pt5/lib/python3.5/site-packages/csbdeep/models/care_standard.py:139: UserWarning: output path for model already exists, files may be overwritten: /data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/DrosophilaDenoisingProjection
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# Epoch 1/100
# 400/400 [==============================] - 805s 2s/step - loss: 0.1261 - mse: 0.0365 - mae: 0.1261 - val_loss: 0.1251 - val_mse: 0.0398 - val_mae: 0.1251
# Epoch 2/100
# 400/400 [==============================] - 800s 2s/step - loss: 0.1144 - mse: 0.0332 - mae: 0.1144 - val_loss: 0.1103 - val_mse: 0.0329 - val_mae: 0.1103
# Epoch 3/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1105 - mse: 0.0320 - mae: 0.1105 - val_loss: 0.1113 - val_mse: 0.0353 - val_mae: 0.1113
# Epoch 4/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1086 - mse: 0.0314 - mae: 0.1086 - val_loss: 0.1082 - val_mse: 0.0309 - val_mae: 0.1082
# Epoch 5/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1076 - mse: 0.0309 - mae: 0.1076 - val_loss: 0.1076 - val_mse: 0.0301 - val_mae: 0.1076
# Epoch 6/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1077 - mse: 0.0309 - mae: 0.1077 - val_loss: 0.1074 - val_mse: 0.0323 - val_mae: 0.1074
# Epoch 7/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1067 - mse: 0.0307 - mae: 0.1067 - val_loss: 0.1052 - val_mse: 0.0294 - val_mae: 0.1052
# Epoch 8/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1071 - mse: 0.0307 - mae: 0.1071 - val_loss: 0.1050 - val_mse: 0.0289 - val_mae: 0.1050
# Epoch 9/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1066 - mse: 0.0303 - mae: 0.1066 - val_loss: 0.1084 - val_mse: 0.0332 - val_mae: 0.1084
# Epoch 10/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.1053 - mse: 0.0300 - mae: 0.1053 - val_loss: 0.1045 - val_mse: 0.0304 - val_mae: 0.1045
# Epoch 11/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1045 - mse: 0.0297 - mae: 0.1045 - val_loss: 0.1053 - val_mse: 0.0309 - val_mae: 0.1053
# Epoch 12/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1044 - mse: 0.0296 - mae: 0.1044 - val_loss: 0.1043 - val_mse: 0.0304 - val_mae: 0.1043
# Epoch 13/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.1042 - mse: 0.0298 - mae: 0.1042 - val_loss: 0.1060 - val_mse: 0.0270 - val_mae: 0.1060
# Epoch 14/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1047 - mse: 0.0297 - mae: 0.1047 - val_loss: 0.1039 - val_mse: 0.0275 - val_mae: 0.1039
# Epoch 15/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1044 - mse: 0.0297 - mae: 0.1044 - val_loss: 0.1027 - val_mse: 0.0291 - val_mae: 0.1027
# Epoch 16/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1042 - mse: 0.0296 - mae: 0.1042 - val_loss: 0.1032 - val_mse: 0.0303 - val_mae: 0.1032
# Epoch 17/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1037 - mse: 0.0295 - mae: 0.1037 - val_loss: 0.1028 - val_mse: 0.0299 - val_mae: 0.1028
# Epoch 18/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.1023 - mse: 0.0288 - mae: 0.1023 - val_loss: 0.1056 - val_mse: 0.0288 - val_mae: 0.1056
# Epoch 19/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1023 - mse: 0.0290 - mae: 0.1023 - val_loss: 0.1033 - val_mse: 0.0288 - val_mae: 0.1033
# Epoch 20/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1030 - mse: 0.0291 - mae: 0.1030 - val_loss: 0.1031 - val_mse: 0.0285 - val_mae: 0.1031
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 21/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1007 - mse: 0.0284 - mae: 0.1007 - val_loss: 0.1013 - val_mse: 0.0288 - val_mae: 0.1013
# Epoch 22/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.1022 - mse: 0.0288 - mae: 0.1022 - val_loss: 0.1021 - val_mse: 0.0304 - val_mae: 0.1021
# Epoch 23/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.1002 - mse: 0.0283 - mae: 0.1002 - val_loss: 0.1022 - val_mse: 0.0307 - val_mae: 0.1022
# Epoch 24/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1005 - mse: 0.0283 - mae: 0.1005 - val_loss: 0.1019 - val_mse: 0.0267 - val_mae: 0.1019
# Epoch 25/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1016 - mse: 0.0288 - mae: 0.1016 - val_loss: 0.1025 - val_mse: 0.0272 - val_mae: 0.1025
# Epoch 26/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0998 - mse: 0.0282 - mae: 0.0998 - val_loss: 0.1007 - val_mse: 0.0278 - val_mae: 0.1007
# Epoch 27/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1010 - mse: 0.0287 - mae: 0.1010 - val_loss: 0.1010 - val_mse: 0.0284 - val_mae: 0.1010
# Epoch 28/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0999 - mse: 0.0280 - mae: 0.0999 - val_loss: 0.1022 - val_mse: 0.0309 - val_mae: 0.1022
# Epoch 29/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.1006 - mse: 0.0283 - mae: 0.1006 - val_loss: 0.1010 - val_mse: 0.0277 - val_mae: 0.1010
# Epoch 30/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0996 - mse: 0.0281 - mae: 0.0996 - val_loss: 0.1010 - val_mse: 0.0293 - val_mae: 0.1010
# Epoch 31/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0997 - mse: 0.0281 - mae: 0.0997 - val_loss: 0.1004 - val_mse: 0.0280 - val_mae: 0.1004
# Epoch 32/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0999 - mse: 0.0282 - mae: 0.0999 - val_loss: 0.1007 - val_mse: 0.0294 - val_mae: 0.1007
# Epoch 33/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.1007 - mse: 0.0284 - mae: 0.1007 - val_loss: 0.1005 - val_mse: 0.0293 - val_mae: 0.1005
# Epoch 34/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0989 - mse: 0.0278 - mae: 0.0989 - val_loss: 0.1006 - val_mse: 0.0285 - val_mae: 0.1006
# Epoch 35/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0984 - mse: 0.0277 - mae: 0.0984 - val_loss: 0.1007 - val_mse: 0.0276 - val_mae: 0.1007
# Epoch 36/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.1004 - mse: 0.0283 - mae: 0.1004 - val_loss: 0.0997 - val_mse: 0.0279 - val_mae: 0.0997
# Epoch 37/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0996 - mse: 0.0281 - mae: 0.0996 - val_loss: 0.1000 - val_mse: 0.0288 - val_mae: 0.1000
# Epoch 38/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0988 - mse: 0.0278 - mae: 0.0988 - val_loss: 0.1001 - val_mse: 0.0290 - val_mae: 0.1001
# Epoch 39/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0990 - mse: 0.0278 - mae: 0.0990 - val_loss: 0.1001 - val_mse: 0.0270 - val_mae: 0.1001
# Epoch 40/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0979 - mse: 0.0275 - mae: 0.0979 - val_loss: 0.0996 - val_mse: 0.0282 - val_mae: 0.0996
# Epoch 41/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0985 - mse: 0.0278 - mae: 0.0985 - val_loss: 0.0998 - val_mse: 0.0271 - val_mae: 0.0998
# Epoch 42/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0985 - mse: 0.0276 - mae: 0.0985 - val_loss: 0.0996 - val_mse: 0.0278 - val_mae: 0.0996
# Epoch 43/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0985 - mse: 0.0276 - mae: 0.0985 - val_loss: 0.1004 - val_mse: 0.0268 - val_mae: 0.1004
# Epoch 44/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0973 - mse: 0.0273 - mae: 0.0973 - val_loss: 0.1007 - val_mse: 0.0267 - val_mae: 0.1007
# Epoch 45/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0975 - mse: 0.0272 - mae: 0.0975 - val_loss: 0.0996 - val_mse: 0.0290 - val_mae: 0.0996
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 46/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0967 - mse: 0.0271 - mae: 0.0967 - val_loss: 0.0990 - val_mse: 0.0280 - val_mae: 0.0990
# Epoch 47/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0970 - mse: 0.0274 - mae: 0.0970 - val_loss: 0.0992 - val_mse: 0.0271 - val_mae: 0.0992
# Epoch 48/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0966 - mse: 0.0270 - mae: 0.0966 - val_loss: 0.0990 - val_mse: 0.0274 - val_mae: 0.0990
# Epoch 49/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0970 - mse: 0.0272 - mae: 0.0970 - val_loss: 0.0989 - val_mse: 0.0272 - val_mae: 0.0989
# Epoch 50/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0959 - mse: 0.0269 - mae: 0.0959 - val_loss: 0.0995 - val_mse: 0.0262 - val_mae: 0.0995
# Epoch 51/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0961 - mse: 0.0269 - mae: 0.0961 - val_loss: 0.0989 - val_mse: 0.0285 - val_mae: 0.0989
# Epoch 52/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0968 - mse: 0.0272 - mae: 0.0968 - val_loss: 0.0990 - val_mse: 0.0265 - val_mae: 0.0990
# Epoch 53/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0958 - mse: 0.0268 - mae: 0.0958 - val_loss: 0.0994 - val_mse: 0.0279 - val_mae: 0.0994
# Epoch 54/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0945 - mse: 0.0264 - mae: 0.0945 - val_loss: 0.0986 - val_mse: 0.0275 - val_mae: 0.0986
# Epoch 55/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0954 - mse: 0.0265 - mae: 0.0954 - val_loss: 0.0986 - val_mse: 0.0276 - val_mae: 0.0986
# Epoch 56/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0945 - mse: 0.0264 - mae: 0.0945 - val_loss: 0.0986 - val_mse: 0.0276 - val_mae: 0.0986
# Epoch 57/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0956 - mse: 0.0268 - mae: 0.0956 - val_loss: 0.0993 - val_mse: 0.0267 - val_mae: 0.0993
# Epoch 58/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0948 - mse: 0.0265 - mae: 0.0948 - val_loss: 0.0985 - val_mse: 0.0280 - val_mae: 0.0985
# Epoch 59/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0944 - mse: 0.0263 - mae: 0.0944 - val_loss: 0.0988 - val_mse: 0.0270 - val_mae: 0.0988
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 60/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0937 - mse: 0.0262 - mae: 0.0937 - val_loss: 0.0986 - val_mse: 0.0270 - val_mae: 0.0986
# Epoch 61/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0939 - mse: 0.0262 - mae: 0.0939 - val_loss: 0.0984 - val_mse: 0.0279 - val_mae: 0.0984
# Epoch 62/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0946 - mse: 0.0264 - mae: 0.0946 - val_loss: 0.0983 - val_mse: 0.0272 - val_mae: 0.0983
# Epoch 63/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0934 - mse: 0.0260 - mae: 0.0934 - val_loss: 0.0985 - val_mse: 0.0271 - val_mae: 0.0985
# Epoch 64/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0941 - mse: 0.0263 - mae: 0.0941 - val_loss: 0.0984 - val_mse: 0.0272 - val_mae: 0.0984
# Epoch 65/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0935 - mse: 0.0260 - mae: 0.0935 - val_loss: 0.0992 - val_mse: 0.0262 - val_mae: 0.0992
# Epoch 66/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0932 - mse: 0.0260 - mae: 0.0932 - val_loss: 0.0985 - val_mse: 0.0279 - val_mae: 0.0985
# Epoch 67/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0925 - mse: 0.0257 - mae: 0.0925 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 68/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0939 - mse: 0.0262 - mae: 0.0939 - val_loss: 0.0985 - val_mse: 0.0270 - val_mae: 0.0985
# Epoch 69/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0931 - mse: 0.0259 - mae: 0.0931 - val_loss: 0.0983 - val_mse: 0.0273 - val_mae: 0.0983
# Epoch 70/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0915 - mse: 0.0253 - mae: 0.0915 - val_loss: 0.0984 - val_mse: 0.0276 - val_mae: 0.0984
# Epoch 71/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0925 - mse: 0.0257 - mae: 0.0925 - val_loss: 0.0984 - val_mse: 0.0276 - val_mae: 0.0984
# Epoch 72/100
# 400/400 [==============================] - 798s 2s/step - loss: 0.0932 - mse: 0.0259 - mae: 0.0932 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 73/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0925 - mse: 0.0258 - mae: 0.0925 - val_loss: 0.0984 - val_mse: 0.0275 - val_mae: 0.0984
# Epoch 74/100
# 400/400 [==============================] - 798s 2s/step - loss: 0.0921 - mse: 0.0256 - mae: 0.0921 - val_loss: 0.0984 - val_mse: 0.0271 - val_mae: 0.0984
# Epoch 75/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0929 - mse: 0.0259 - mae: 0.0929 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 76/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0919 - mse: 0.0255 - mae: 0.0919 - val_loss: 0.0984 - val_mse: 0.0272 - val_mae: 0.0984
# Epoch 77/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0925 - mse: 0.0256 - mae: 0.0925 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 78/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0914 - mse: 0.0254 - mae: 0.0914 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 79/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0913 - mse: 0.0253 - mae: 0.0913 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 80/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0934 - mse: 0.0260 - mae: 0.0934 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 81/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0916 - mse: 0.0254 - mae: 0.0916 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 82/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0911 - mse: 0.0252 - mae: 0.0911 - val_loss: 0.0985 - val_mse: 0.0275 - val_mae: 0.0985
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 83/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0923 - mse: 0.0257 - mae: 0.0923 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 84/100
# 400/400 [==============================] - 797s 2s/step - loss: 0.0926 - mse: 0.0257 - mae: 0.0926 - val_loss: 0.0985 - val_mse: 0.0272 - val_mae: 0.0985
# Epoch 85/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0922 - mse: 0.0256 - mae: 0.0922 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 86/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0914 - mse: 0.0254 - mae: 0.0914 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 87/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0922 - mse: 0.0256 - mae: 0.0922 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 88/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0919 - mse: 0.0256 - mae: 0.0919 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 89/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0919 - mse: 0.0256 - mae: 0.0919 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 90/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0920 - mse: 0.0255 - mae: 0.0920 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 91/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0915 - mse: 0.0253 - mae: 0.0915 - val_loss: 0.0985 - val_mse: 0.0273 - val_mae: 0.0985
# Epoch 92/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0912 - mse: 0.0254 - mae: 0.0912 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 93/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0917 - mse: 0.0254 - mae: 0.0917 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 94/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0920 - mse: 0.0254 - mae: 0.0920 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 95/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0924 - mse: 0.0257 - mae: 0.0924 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 96/100
# 400/400 [==============================] - 795s 2s/step - loss: 0.0907 - mse: 0.0252 - mae: 0.0907 - val_loss: 0.0984 - val_mse: 0.0273 - val_mae: 0.0984
# Epoch 97/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0922 - mse: 0.0255 - mae: 0.0922 - val_loss: 0.0985 - val_mse: 0.0273 - val_mae: 0.0985
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 98/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0925 - mse: 0.0257 - mae: 0.0925 - val_loss: 0.0984 - val_mse: 0.0274 - val_mae: 0.0984
# Epoch 99/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0914 - mse: 0.0254 - mae: 0.0914 - val_loss: 0.0985 - val_mse: 0.0273 - val_mae: 0.0985
# Epoch 100/100
# 400/400 [==============================] - 796s 2s/step - loss: 0.0923 - mse: 0.0258 - mae: 0.0923 - val_loss: 0.0985 - val_mse: 0.0273 - val_mae: 0.0985
#
# Loading network weights from 'weights_best.h5'.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);
# Out:
# ['loss', 'lr', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %%
model.export_TF()
# Out:
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmpmekzrj5x/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/DrosophilaDenoisingProjection/TF_SavedModel.zip
